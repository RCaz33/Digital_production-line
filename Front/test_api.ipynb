# %%
import requests

# %%
response = requests.get(f'http://127.0.0.1:8000/matieres_premieres/')

# %%
data.MP_nom.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
import pandas as pd

data = pd.DataFrame(response.json())

# data.loc[data.MP_nom == 'Potassium'].sort_values('MP_id')['MP_ref_fournisseur'].values[-1]

data
# Out:
#      MP_id     MP_nom MP_codeCW    MP_ref_fournisseur    MP_date_reception  \
# 0        3  Potassium    CW_003  x13TX0KUFVYUNy2XVEhL  2023-01-01T00:00:00
# 1        4  Potassium    CW_003  YxQGVyvo79BqZPTXAwlJ  2023-01-01T00:00:00
# 2        5  Potassium    CW_003  fCEpeE0iooQ8hQ0wwxrJ  2023-01-01T00:00:00
# 3        6  Potassium    CW_003  tnpsvS3t8DEObyGJF2vb  2023-01-01T00:00:00
# 4        7     Carbon    CW_002  jkMzu9prZwZLsLk58L8G  2023-01-01T00:00:00
# ..     ...        ...       ...                   ...                  ...
# 196    199        THF    CW_001  wWKcPE9iH9MnfGNyYF0E  2023-01-01T00:00:00
# 197    200  Potassium    CW_003  G6lgpTWzuKO9phEGuo0R  2023-01-01T00:00:00
# 198    201     Carbon    CW_002  z0VY5E5hvUa46holK4SD  2023-01-01T00:00:00
# 199    202     Carbon    CW_002  1azfdqffUEQhdjSPiXpR  2023-01-01T00:00:00
# 200    203        THF    CW_001  cTSItmmQ6bsjMLRIAe1I  2023-01-01T00:00:00
#
#      MP_quantite MP_unite                         MP_Analyses
# 0          721.0       kg  codes_analyses_separated_by_commas
# 1          420.0       kg  codes_analyses_separated_by_commas
# 2          363.0       kg  codes_analyses_separated_by_commas
# 3          570.0       kg  codes_analyses_separated_by_commas
# 4          997.0       kg  codes_analyses_separated_by_commas
# ..           ...      ...                                 ...
# 196        795.0        L  codes_analyses_separated_by_commas
# 197        894.0       kg  codes_analyses_separated_by_commas
# 198        907.0       kg  codes_analyses_separated_by_commas
# 199        513.0       kg  codes_analyses_separated_by_commas
# 200        887.0        L  codes_analyses_separated_by_commas
#
# [201 rows x 8 columns]

# %%
response = requests.get(f'http://127.0.0.1:8000/KC8/')


import pandas as pd

_ = pd.DataFrame(response.json())

# %%
_
# Out:
#      Batch_KC8_id Batch_KC8_name       Batch_KC8_date Batch_KC8_Technicien  \
# 0               1         Carbon  2024-02-03T00:00:00                   LB
# 1               2         Carbon  2024-09-10T00:00:00                   RS
# 2               3         Carbon  2024-10-27T00:00:00                   WL
# 3               4         Carbon  2024-08-15T00:00:00                   WL
# 4               5      Potassium  2023-07-31T00:00:00                   TB
# ..            ...            ...                  ...                  ...
# 196           197            THF  2023-10-16T00:00:00                   TB
# 197           198            THF  2024-10-29T00:00:00                   LB
# 198           199            THF  2024-04-28T00:00:00                   LC
# 199           200            THF  2024-10-19T00:00:00                   LB
# 200           201      Potassium  2025-01-02T00:00:00                   TB
#
#         Batch_KC8_K_batch     Batch_KC8_C_batch  Batch_KC8_masse  \
# 0    su62fAsdKh7z48KafiUC  26IvLbkH0QbocehMBq8v              300
# 1    SJaEOTT4KNYjPTIShmre  vB9UFj1B6WRJ6ODa1Pfr              300
# 2    Zlu6pDsq3GiCtFjwS7hV  AjlIx5FTGaPhWgWAGvap              300
# 3    x13TX0KUFVYUNy2XVEhL  8HCq0in0hAEcpKS0ehJ0              200
# 4    su62fAsdKh7z48KafiUC  qX8AcGp0pSYAS8TAmtzd              200
# ..                    ...                   ...              ...
# 196  YxQGVyvo79BqZPTXAwlJ  QW99NjrNn1s9vzG9EAw8              200
# 197  Fc9S2Gv4Qp1iyAAWQxh9  wNRhWrytKM0XC5mBBbN7              200
# 198  9KAuqrOKacwwQe5ehmgj  hdPhCrGfxcOfspqZrdZr              300
# 199  V79Vm7mn0Ii5xCR4y9vx  rOjGbSk6tYbL0eNd1rgC              300
# 200  Zlu6pDsq3GiCtFjwS7hV  5x3xJFA2bpuyW0sL8zSL              300
#
#      Batch_KC8_Temperature  Batch_KC8_Agitation Batch_KC8_heure_debut  \
# 0                     60.0                  300   2024-02-03T12:00:00
# 1                     50.0                  250   2024-09-10T12:00:00
# 2                     70.0                  250   2024-10-27T12:00:00
# 3                     60.0                  250   2024-08-15T12:00:00
# 4                     60.0                  300   2023-07-31T12:00:00
# ..                     ...                  ...                   ...
# 196                   50.0                  250   2023-10-16T12:00:00
# 197                   60.0                  250   2024-10-29T12:00:00
# 198                   60.0                  250   2024-04-28T12:00:00
# 199                   60.0                  300   2024-10-19T12:00:00
# 200                   70.0                  250   2025-01-02T12:00:00
#
#      Batch_KC8_heure_fin  Batch_KC8_room_HR  Batch_KC8_room_T  \
# 0    2024-02-03T13:00:00               22.0               0.2
# 1    2024-09-10T14:00:00               28.0               0.3
# 2    2024-10-27T14:00:00               23.0               0.2
# 3    2024-08-15T14:00:00               30.0               0.2
# 4    2023-07-31T13:00:00               20.0               0.3
# ..                   ...                ...               ...
# 196  2023-10-16T14:00:00               24.0               0.1
# 197  2024-10-29T13:00:00               24.0               0.1
# 198  2024-04-28T14:00:00               26.0               0.3
# 199  2024-10-19T13:00:00               28.0               0.3
# 200  2025-01-02T15:00:00               29.0               0.3
#
#                      Batch_KC8_Analyses
# 0    codes_analyses_separated_by_commas
# 1    codes_analyses_separated_by_commas
# 2    codes_analyses_separated_by_commas
# 3    codes_analyses_separated_by_commas
# 4    codes_analyses_separated_by_commas
# ..                                  ...
# 196  codes_analyses_separated_by_commas
# 197  codes_analyses_separated_by_commas
# 198  codes_analyses_separated_by_commas
# 199  codes_analyses_separated_by_commas
# 200  codes_analyses_separated_by_commas
#
# [201 rows x 14 columns]

# %%
np.max(KC8_all.Batch_KC8_id)
# Out:
# np.int64(601)

# %%
KC8_all.loc[KC8_all.Batch_KC8_id==np.max(KC8_all.Batch_KC8_id),'Batch_KC8_name'].values[0]
# Out:
# 'K2337'

# %%
KC8_all.loc[199,'Batch_KC8_name']
# Out:
# 'K2337'

# %%
import datetime
today = datetime.datetime.now()
today.strftime('%d/%m/%y')
# Out:
# '22/01/25'

# %%
import numpy as np
response = requests.get(f'http://127.0.0.1:8000/KC8/')
KC8_all = pd.DataFrame(response.json())
KC8_all.iloc[np.max(KC8_all.index),'Batch_KC8_name']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Applications/anaconda3/envs/CarbonWaters/lib/python3.13/site-packages/pandas/core/indexing.py:966, in _LocationIndexer._validate_tuple_indexer(self, key)
#     965 try:
# --> 966     self._validate_key(k, i)
#     967 except ValueError as err:
#
# File /Applications/anaconda3/envs/CarbonWaters/lib/python3.13/site-packages/pandas/core/indexing.py:1614, in _iLocIndexer._validate_key(self, key, axis)
#    1613 else:
# -> 1614     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 4
#       2 response = requests.get(f'http://127.0.0.1:8000/KC8/')
#       3 KC8_all = pd.DataFrame(response.json())
# ----> 4 KC8_all.iloc[np.max(KC8_all.index),'Batch_KC8_name']
#
# File /Applications/anaconda3/envs/CarbonWaters/lib/python3.13/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#    1187     axis = self.axis or 0
#
# File /Applications/anaconda3/envs/CarbonWaters/lib/python3.13/site-packages/pandas/core/indexing.py:1690, in _iLocIndexer._getitem_tuple(self, tup)
#    1689 def _getitem_tuple(self, tup: tuple):
# -> 1690     tup = self._validate_tuple_indexer(tup)
#    1691     with suppress(IndexingError):
#    1692         return self._getitem_lowerdim(tup)
#
# File /Applications/anaconda3/envs/CarbonWaters/lib/python3.13/site-packages/pandas/core/indexing.py:968, in _LocationIndexer._validate_tuple_indexer(self, key)
#     966         self._validate_key(k, i)
#     967     except ValueError as err:
# --> 968         raise ValueError(
#     969             "Location based indexing can only have "
#     970             f"[{self._valid_types}] types"
#     971         ) from err
#     972 return key
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types
