# %%
import requests

# %%
response = requests.get(url='http://127.0.0.1:8000/public-endpoint')
response.status_code
# Out:
# 200

# %%
response = requests.get(url='http://127.0.0.1:8000/tsne_coordinates/2025-02-26')
response.status_code
# Out:
# 200

# %%
headers = {
    "Content-Type": "application/json",
    "Unsupervized-API-Key": "12345678"  # Replace with your actual API key
}

response = requests.post(url='http://127.0.0.1:8000/transform_data',headers=headers)
response.content
# Out:
# b'{"detail":[{"type":"missing","loc":["body"],"msg":"Field required","input":null}]}'
